# %% [markdown]
# # PCAP Exam blocks

# %% [markdown]
# ## 01 Modules and Packages

# %%
# A function named f() is included in a module name m, and the module is a part of a package named p. 
# Which of the following code snippets allows you to properly invoke the function?

import p.m import f     # from package.module import function
f()

OR

import p.m
p.m.f()

# %%
# The follwing code snippet is used to import and invoke the c() function. What is always true about the function and its environment?
import a.b
a.b.c()

# The c() function is contained in the b module
# The b component is a module, and it is contained inside the a package, or is a submodule of a

# %%
# What is true abou the built-in dir() mechanism in the context of modules and packages?
# It is a function which can be invoked with a module passed as an argument in order to obtain the module content

# %%
# What is tru about sys.path?
# It is a list of strings which indicates all directories / folders scanned by Python in order to find the specific modules

# %%
# Which of the following functions come from the math module?
# hypot() - finds the length of the hypotenuse
# sqrt() - evaluates the square root of the argument

# %%
# A programmer needs to use the following functions: machine(), choice(), and system(). 
# Which modules have to be imported to make this possible?
# random - containts choice() function - returns random element chosen from a sequence
# platform - contains machine() function - returns string describing the machine type, and system()

# %%
# What is the expected output of the following code?
import math
x = -1.5
print(abs(math.floor(x)+ math.ceil(x))) # floor = -2, ceil = -1 –-> abs(-3) --> 3
# Out:
# 3

# %%
# What is the expected output of the following code?
import random
random.seed(0)
x = random.choice([1,2])
random.seed(0) # set up same --> number will be same 
y=random.choice([1,2]) # 1 - 1 or 2 -2 --> both = 0
print(x-y)
# Out:
# 0

# %%
# Which of the following statements are true?
# A source file named __init__.py is used to mark a directory/folder as containing a Python package, and to initialize the package
# The variable named __name__ is a string containing the module name

# %%
# Which of the following statements are true about the __pycache__ directory/folder?
# It containts semi-compiled module code
# It is created automatically

# %%
# What is true about how Python looks for modules/packages?
# The directory from which the code has been run is always searech through

# %%
# Which of the following variables will Python consider to be private?
__privatedata # always starts with 2 underscores: __
