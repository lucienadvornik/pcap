# %% [markdown]
# # Mock PCAP Exam

# %% [markdown]
# ### 01) Modules and Packages

# %%
# When working with modules, Python uses an optimization technique by creating a __pychache__ folder with some semi-compiled code. What is the extension that Python uses for files in this folder?
# pyc

# %%
# Imagine that you have a file named myfile.py. What will be the output if you place the following line in the file and then run the file? print(__name__)
# __main__

# %%
# Which of the following statement is/are correct?
import random
participants = ['A', 'B', 'C', 'D', 'E', 'F']
print(random.choice(participants))

# It is difficult/impossible to predict the output of the program upfront
# This program may print the letter A to the output

# %%
# The following piece of code...
import random
print(dir(random))
# will show a list of all entities available in the random module

# %%
# What will be the output of the following code?
import math
print(math.ceil(3.0) + math.floor(4.9) + 3) # 3 + 4 + 3 = 10
# Out:
# 10

# %%
# What will be imported after running the following code?
from foo.bar import buzz

# from PACKAGE.MODULE import ENTITY
# --> entity buzz from module bar in package foo

# %% [markdown]
# ### 02) Strings

# %%
# What will be the output of the following code?
# isalnu() checks if the string contains only alphanumeric characters
nickname = 'Adam_12'
if nickname.isalnum():
 print('OK')
else:
 print('not OK') # there is '_'
# Out:
# not OK

# %%
# Which line of code should be inserted into the indicated space:

inpt = ['Adam', 'Mary', 'Kate']
# enter your line here
print(res)
To see the following output?

Adam-Mary-Kate

# %%
# Compared to ASCII, each character encoded in UTF-8...

# %%
# What will be the output?
print(chr(ord('a') + 2))

# %%
# What will be the output?
print('20' > '8' or '20' > 8)

# %%
# What will be the output after running the following code?
print(len("\\\\"))

# %%
# Which of the following pieces of code will return the number 7 to the output?

# %%
# What will be the output of the following code?

longone = """Hi
There"""
 
print(len(longone))

# %% [markdown]
# ### 03) Object-Oriented Programming

# %% [markdown]
# ### 04) Exceptions

# %%
# What will happen if you provide a string argument '1,0' to the float() function?
float('1, 0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 # What will happen if you provide a string argument '1,0' to the float() function?
# ----> 2 float('1, 0')
#
# ValueError: could not convert string to float: '1, 0'

# %%
# Choose all correct statements. A self-defined exception class...
# - does not have to define its own constructor
# - may inherit from the Exception class

# %%
# What will the following statement do?
assert value != 0
# - it will raise an exception when value = 0

# %%
# What will be the output of the following program?

try:
 raise Exception
except:
 print('a')
except BaseException:
 print('b')
except Exception:
 print('c')

# SyntaxError
# Out:
#   Cell In[2], line 5
#     except:
#     ^
# SyntaxError: default 'except:' must be last

# %%
# What will be the output of the following program?

try:
 raise Exception(0, 1, [0, 1]) # creates an exception object with three arguments
# when raising an exception like this, all arguments are stored in a tuple called e.args; e.args == (0, 1, [0, 1])
except Exception as e:
 print(len(e.args))

# 3
# Out:
# 3

# %% [markdown]
# ### 05) Miscellaneous

# %%
# What will be the output?

def a():
 hey = 5
 
 def b():
  print(hey)
 
 return b
 
x = a()
print(x())
# Out:
# 5
# None

# %%
# Suppose that a file was correctly opened in the "r" mode with the "stream" variable. What will the following line do?

kb = stream.read(1)
# Read one character from the stream

# %%
# The following line:

for item in open('file.txt', 'rt'):

# .. is correct because open() return an iterable object

# %%
# Which of the following will produce this list? [['*', '*'], ['*', '*']]

[['*' for i in range(1, 3)] for j in range(2)]
# Out:
# [['*', '*'], ['*', '*']]

# %%
# What will be the output?

inpt = ['a', 'b', 'c', 'd']
print(list(map(lambda a: a+a, inpt)))

# ['aa', 'bb', 'cc', 'dd']
# Out:
# ['aa', 'bb', 'cc', 'dd']

# %%
# Suppose that a file was correctly open with the "stream" text stream 
# and all of its content has been already read. 
# The cursor of the stream points to the end of the file.
# What will now happen if we invoke read(10) on the stream?

# The function will return an empty string

# %%
# What will be the output?
print(list(map(lambda x: x + 5, [int(bytearray(10)[0])])))
# Out:
# [5]

# %%
# Which of the following instructions should be placed 
# in the specified place to correctly finish working with the stream?

try:
 stream = open('file.txt')
 character = stream.read(5) 
 # insert line here
except Exception as e:
 print('An error occurred: ', e)

# stream.close()
# Out:
# An error occurred:  [Errno 2] No such file or directory: 'file.txt'

# %%
# Choose all correct statements about the strerror function.

# It returns a short error message for the given error code
# It comes from the os module
